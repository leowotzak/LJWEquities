# %%
import os
import pandas as pd
from dotenv import load_dotenv
from arcgis.gis import GIS

load_dotenv()

# * Geocoding require arcGIS credentials and a login
USER, PASS = os.environ.get('USERNAME'), os.environ.get('PASSWORD')
my_gis = GIS("http://www.arcgis.com", username=USER, password=PASS)

# %%
addresses = pd.read_excel(
    'demographic_data.xlsx', index_col=0, squeeze=True, dtype="string"
)
addresses
# Out:
#                                                       Full Address ID  \
# Name
# Alafaya                    81 Alafaya Woods Blvd, Oviedo, FL 32765  0
# Auburn                 2222 Grass Valley Highway, Auburn, CA 95603  0
# Broadway                      30 25th St. SE., Rochester, MN 55904  0
# Cobbler                           1020 Summit St., Elgin, IL 60120  0
# Durham                     3457 Hillsborough Rd., Durham, NC 27705  0
# Eagan                        1276 Town Centre Dr., Eagan, MN 55123  0
# Heritage                 20074 Heritage Drive, Lakeville, MN 55044  0
# Jacaranda                8249 W Sunrise Blvd, Plantation, FL 33322  0
# Kauai                            4-831 Kuhio Hwy, Kapa'a, HI 96746  0
# Marketplace                      3002 S 31st St., Temple, TX 76502  0
# Northlake               1814 N Causeway Blvd, Mandeville, LA 70471  0
# Preston Trail                  17194 Preston Rd., Dallas, TX 75248  0
# Rillito                          4206 N 1st Ave., Tucson, AZ 85719  0
# Riverview                     5116 N Roxboro St., Durham, NC 27704  0
# Scottsdale North  6310 N Scottsdale Rd., Paradise Valley, AZ 85253  0
# Forest Hill                 9235 Poplar Ave., Germantown, TN 38138  0
# Sprouts                     316 Grapevine Highway, Hurst, TX 76054  0
# Ventana                       6890 E Sunrise Dr., Tucson, AZ 85750  0
#
#                  OBJECTID sourceCountry                   X  \
# Name
# Alafaya                 1            US  -81.20519903544579
# Auburn                  1            US   -121.091083009304
# Broadway                1            US   -92.4595449736619
# Cobbler                 1            US  -88.25470901478766
# Durham                  1            US  -78.94819902207153
# Eagan                   1            US  -93.16063375825092
# Heritage                1            US  -93.24122252015539
# Jacaranda               1            US  -80.26215999399412
# Kauai                   1            US  -159.3212380163936
# Marketplace             1            US  -97.37009200145029
# Northlake               1            US  -90.09054001890614
# Preston Trail           1            US  -96.80220699720188
# Rillito                 1            US  -110.9605430024492
# Riverview               1            US   -78.9064119657997
# Scottsdale North        1            US  -111.9264130070463
# Forest Hill             1            US  -89.75541300594593
# Sprouts                 1            US   -97.1719400385264
# Ventana                 1            US  -110.8456079991747
#
#                                   Y    areaType bufferUnits bufferUnitsAlias  \
# Name
# Alafaya           28.65083900217472  RingBuffer   esriMiles            Miles
# Auburn            38.93476201171742  RingBuffer   esriMiles            Miles
# Broadway          43.98302002064094  RingBuffer   esriMiles            Miles
# Cobbler           42.04793098012354  RingBuffer   esriMiles            Miles
# Durham            36.01864001993958  RingBuffer   esriMiles            Miles
# Eagan             44.83169702106701  RingBuffer   esriMiles            Miles
# Heritage          44.65799076542314  RingBuffer   esriMiles            Miles
# Jacaranda         26.14831699344717  RingBuffer   esriMiles            Miles
# Kauai             22.06281900967602  RingBuffer   esriMiles            Miles
# Marketplace       31.07189800640191  RingBuffer   esriMiles            Miles
# Northlake         30.39353599790182  RingBuffer   esriMiles            Miles
# Preston Trail     32.98535599512297  RingBuffer   esriMiles            Miles
# Rillito           32.28322399886476  RingBuffer   esriMiles            Miles
# Riverview         36.06913398768246  RingBuffer   esriMiles            Miles
# Scottsdale North  33.53028598405899  RingBuffer   esriMiles            Miles
# Forest Hill       35.06463598230138  RingBuffer   esriMiles            Miles
# Sprouts           32.86930498335012  RingBuffer   esriMiles            Miles
# Ventana           32.30682601328326  RingBuffer   esriMiles            Miles
#
#                  bufferRadii                  aggregationMethod  \
# Name
# Alafaya                    1  BlockApportionment:US.BlockGroups
# Auburn                     1  BlockApportionment:US.BlockGroups
# Broadway                   1  BlockApportionment:US.BlockGroups
# Cobbler                    1  BlockApportionment:US.BlockGroups
# Durham                     1  BlockApportionment:US.BlockGroups
# Eagan                      1  BlockApportionment:US.BlockGroups
# Heritage                   1  BlockApportionment:US.BlockGroups
# Jacaranda                  1  BlockApportionment:US.BlockGroups
# Kauai                      1  BlockApportionment:US.BlockGroups
# Marketplace                1  BlockApportionment:US.BlockGroups
# Northlake                  1  BlockApportionment:US.BlockGroups
# Preston Trail              1  BlockApportionment:US.BlockGroups
# Rillito                    1  BlockApportionment:US.BlockGroups
# Riverview                  1  BlockApportionment:US.BlockGroups
# Scottsdale North           1  BlockApportionment:US.BlockGroups
# Forest Hill                1  BlockApportionment:US.BlockGroups
# Sprouts                    1  BlockApportionment:US.BlockGroups
# Ventana                    1  BlockApportionment:US.BlockGroups
#
#                  populationToPolygonSizeRating apportionmentConfidence  \
# Name
# Alafaya                                  2.191                   2.576
# Auburn                                   2.191                   2.576
# Broadway                                 2.191                   2.576
# Cobbler                                  2.191                   2.576
# Durham                                   2.191                   2.576
# Eagan                                    2.191                   2.576
# Heritage                                 2.191                   2.576
# Jacaranda                                2.191                   2.576
# Kauai                                    2.191                   2.576
# Marketplace                              2.191                   2.576
# Northlake                                2.191                   2.576
# Preston Trail                            2.191                   2.576
# Rillito                                  2.191                   2.576
# Riverview                                2.191                   2.576
# Scottsdale North                         2.191                   2.576
# Forest Hill                              2.191                   2.576
# Sprouts                                  2.191                   2.576
# Ventana                                  2.191                   2.576
#
#                  HasData TOTPOP TOTHH AVGHHSZ TOTMALES TOTFEMALES  \
# Name
# Alafaya                1   9023  3288    2.71     4428       4595
# Auburn                 1   7064  2713    2.36     3466       3599
# Broadway               1   6038  2302    2.59     2965       3073
# Cobbler                1  19408  5954    3.25     9661       9746
# Durham                 1  10793  5186    2.03     5574       5220
# Eagan                  1   9520  4562    2.07     4573       4947
# Heritage               1   6992  2749    2.54     3397       3595
# Jacaranda              1  21605  9172    2.35     9903      11703
# Kauai                  1   1053   407    2.53      549        503
# Marketplace            1  10429  4616    2.17     4823       5606
# Northlake              1   7987  3121    2.55     3817       4170
# Preston Trail          1  10592  4813     2.2     5134       5458
# Rillito                1  18057  8222    2.19     8844       9213
# Riverview              1   5394  2135    2.52     2460       2934
# Scottsdale North       1   5821  3154    1.84     2644       3177
# Forest Hill            1   3513  1271    2.76     1756       1758
# Sprouts                1  10304  3860    2.63     4950       5355
# Ventana                1   4685  2310    2.03     2203       2481
#
#                                                               SHAPE
# Name
# Alafaya           {'rings': [[[-81.20519903544579, 28.6653598459...
# Auburn            {'rings': [[[-121.09108300930404, 38.949258757...
# Broadway          {'rings': [[[-92.4595449736619, 43.99750402296...
# Cobbler           {'rings': [[[-88.25470901478768, 42.0624198980...
# Durham            {'rings': [[[-78.94819902207155, 36.0331439380...
# Eagan             {'rings': [[[-93.16063375825091, 44.8461788626...
# Heritage          {'rings': [[[-93.24122252015539, 44.6724730493...
# Jacaranda         {'rings': [[[-80.26215999399412, 26.1628430488...
# Kauai             {'rings': [[[-159.3212380163936, 22.0773528260...
# Marketplace       {'rings': [[[-97.37009200145029, 31.0864135221...
# Northlake         {'rings': [[[-90.09054001890614, 30.4080530326...
# Preston Trail     {'rings': [[[-96.80220699720188, 32.9998671263...
# Rillito           {'rings': [[[-110.96054300244923, 32.297736755...
# Riverview         {'rings': [[[-78.90641196579973, 36.0836377833...
# Scottsdale North  {'rings': [[[-111.92641300704629, 33.544795841...
# Forest Hill       {'rings': [[[-89.75541300594593, 35.0791421999...
# Sprouts           {'rings': [[[-97.1719400385264, 32.88381638442...
# Ventana           {'rings': [[[-110.84560799917466, 32.321338715...

# %%
my_map = my_gis.map("United States")
my_map
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-dfe30625-d45d-4bf3-bc91-ae3973894b5a"><img src=""></img></div>
# <div class="map-html-embed-preview-dfe30625-d45d-4bf3-bc91-ae3973894b5a"></div>
